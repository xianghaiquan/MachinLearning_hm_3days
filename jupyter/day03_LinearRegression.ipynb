# %%
# 波士顿房价预测

# %%
# from sklearn.datasets import load_boston   # 从sklearn.datasets导入失效
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import SGDRegressor

# %%
# 导入数据
boston = pd.read_csv("../data/boston/boston.csv")
boston
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PIRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
# 特征值
x = boston.drop(["MEDV"], axis=1)
x
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PIRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# ..       ...     ...    ...
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %%
# 目标值
y = boston["MEDV"]
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, Length: 506, dtype: float64

# %%
# 数据集划分
x_train, x_test, y_train, y_test = train_test_split(x, y)
# 标准化
transfer = StandardScaler()
x_train = transfer.fit_transform(x_train)
x_test = transfer.transform(x_test)

# %%
# 模型训练
estimator = LinearRegression()
estimator.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# 模型参数
print("权重系数为：\n", estimator.coef_)
print("偏置为：\n", estimator.intercept_)
# Out:
# 权重系数为：
#  [-3.90871718e-01  7.75698025e-01  2.36582741e-03 -8.18755807e-02
#  -1.54725555e+00  3.35909758e+00 -3.74111354e-01 -2.88594183e+00
#   1.90240865e+00 -2.19160525e+00 -2.12662022e+00  7.81076771e-01
#  -3.00492119e+00]
# 偏置为：
#  22.622427440633253

# %%
# 模型评估-均方误差
y_predict = estimator.predict(x_test)
print("预测房价：\n", y_predict)
error = mean_squared_error(y_test, y_predict)
print("正规方程-均方误差为：\n", error)
# Out:
# 预测房价：
#  [18.76890561 18.23087761 13.22517357 22.59710804 16.9743298  19.42321783
#   5.86023157 20.69372759  9.72990372 14.15424418 19.54886423 17.03949081
#  21.48092112 21.88274499 25.62090427 28.33334578 25.33083237 16.07747334
#   6.36193656 26.90488654 10.85956315 24.63111769 21.02089808 27.56073859
#  24.8714353  19.7422967  28.43374151 19.50739569 16.58884785 24.20725134
#  22.62483785 19.0760815  21.01455882 17.67278895 20.78858007 39.95024751
#  33.5935459  32.75954704 13.49922509 20.53970802 25.66347877 18.59755927
#  32.82466744 19.13964465 17.33493266 22.48472997 31.14572736 24.87514262
#  29.66439417  0.56138478 23.39952832 25.58128573 22.46465002 19.44550939
#  32.50154243 21.51437117 14.81284447 21.24375295 13.4139275  19.99608394
#  20.449495   14.03826625 35.7636221  37.25036215 19.12993298 21.43057728
#  31.70709795 13.4617981  16.98874141 15.50013933 18.79409635 34.59955628
#  26.54095493 15.33963501 21.83377159 19.084015   20.72178405 17.1663877
#  32.43678252 42.27836962 28.90414216 19.9263077  21.03770662 24.85656162
#  12.70082176 19.9125477  20.29828615 17.03367089 33.16495204 38.04896771
#  19.15873291 22.62386904 20.37295838 33.43717873 17.65365493 22.07137036
#  31.51395013 10.86998086 19.76851509 28.91651866 14.18541946 39.49915797
#  14.24224136 20.83528647 19.91369588 30.42249067 25.89631025 18.86176559
#  15.88495378 35.35614242 20.55955216  6.14348868 15.83715012 27.46923766
#  24.27131156 22.46297965 20.63575503  6.14285566 26.46138309  6.51543965
#  16.62309325 17.5789669  16.61630901 26.23689122 16.70271315 19.49452245
#  24.52854934]
# 正规方程-均方误差为：
#  34.98973924221291

# %% [markdown]
# ### 梯度下降

# %%
# SGD模型训练
estimator = SGDRegressor(learning_rate="constant", eta0=0.001, max_iter=10000)
estimator.fit(x_train, y_train)
# Out:
# SGDRegressor(eta0=0.001, learning_rate='constant', max_iter=10000)

# %%
# 模型参数
print("权重系数为：\n", estimator.coef_)
print("偏置为：\n", estimator.intercept_)
# Out:
# 权重系数为：
#  [-0.283961    0.62370033 -0.31760437 -0.04529157 -1.28088645  3.44470864
#  -0.42135193 -2.71561886  1.15075803 -1.41282518 -2.06919328  0.79893369
#  -3.00159254]
# 偏置为：
#  [22.62673931]

# %%
# 模型评估
y_predict = estimator.predict(x_test)
print("预测房价：\n", y_predict)
error = mean_squared_error(y_test, y_predict)
print("正规方程-均方误差为：\n", error)
# Out:
# 预测房价：
#  [18.78060576 17.98920086 13.35214252 21.46218458 16.93708314 19.33467858
#   5.53087474 20.98876035  9.7495706  14.4931776  19.59835239 17.77670097
#  21.58187961 21.95436688 25.71011167 28.14134948 25.16578761 16.20382227
#   6.36234772 26.78250256 11.48553097 24.55385826 20.91265456 27.73984303
#  24.72445933 19.99224565 28.44542645 19.6938636  16.63595072 24.09245012
#  22.35785284 19.07100469 21.01330883 17.72986328 21.08387205 40.20620477
#  33.47640361 32.7185193  13.64331221 20.78945057 25.70737606 18.30629203
#  32.69828879 19.41613638 17.74928461 22.13392426 31.25427331 25.02433403
#  29.58323265  0.24171784 23.34939297 25.9721108  22.36687492 19.7027145
#  32.31193884 21.39149362 15.16392827 20.96138806 13.82863885 19.49703823
#  21.34469958 13.82028323 35.74024163 36.82798015 19.31054578 21.70273993
#  31.76894606 13.20499117 16.97220967 14.2709745  19.82988001 34.91097064
#  26.38534299 15.15106306 21.85879063 19.06943041 19.53960675 17.36284855
#  32.47309234 42.08015553 29.11915463 19.57763159 21.33456859 25.16022521
#  12.52049794 19.98425488 20.30210235 16.74364209 33.05902818 37.91857781
#  19.39381532 22.42917981 20.65909376 33.28634895 17.64792954 22.13229131
#  31.81694944 10.82334914 19.50088017 28.94755192 14.25037405 39.17259841
#  14.07135846 20.65568532 20.16490183 30.5644243  25.95560537 19.15406173
#  16.02510898 35.25548408 20.81673995  5.95573813 15.45418586 27.34670684
#  24.00170098 22.1101678  20.95049209  6.10167203 26.14620889  6.19733862
#  16.57372541 17.77664744 17.4620293  25.92327621 16.84418318 19.35629378
#  24.45684468]
# 正规方程-均方误差为：
#  35.76515113731151
